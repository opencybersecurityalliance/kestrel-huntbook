# %% [markdown]
# # Inspect a Variable
#
# After you `GET` entities from data sources, the obvious next step is to inspect them, conceive the next hunt steps, and create/revise the threat hypothesis.

# %% [markdown]
# ## What you will learn
#
# 0. What are the inspection commands?
# 1. How to show information like attributes of a variable?
# 2. How to display entities with complete information in a variable?
# 3. How to display select attributes of entities in a variable?
# 4. What are the common attributes for a type of entitiy?
# 5. Exercise: get and disp remote IPs from the monitored host

# %% [markdown]
# ### 0. What are the inspection commands?
#
# Kestrel has two command to inspect entities in a variable:
# - show details of a variable with [INFO](https://kestrel.readthedocs.io/en/latest/language.html#info)
# - display entities in a variable with [DISP](https://kestrel.readthedocs.io/en/latest/language.html#disp)

# %% [markdown]
# ### 1. How to show information like attributes of a variable?
#
# Once you have a variable `varx`, just `INFO varx` to show all details such as attributes of the entities:

# %%
# get scheduler process
scheduler = GET process
            FROM file:///tmp/lab101.json
            WHERE [process:pid = 2224]
            START t'2021-04-03T00:00:00Z' STOP t'2021-04-04T00:00:00Z'
          
# show details of variable `scheduler`
INFO scheduler
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>Entity Type</td>
#       <td>process</td>
#     </tr>
#     <tr>
#       <td>Number of Entities</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Number of Records</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>Entity Attributes</td>
#       <td>type, name, pid, command_line, id, first_observed, last_observed, number_observed</td>
#     </tr>
#     <tr>
#       <td>Indirect Attributes</td>
#       <td>[binary_ref.type, binary_ref.name, binary_ref.parent_directory_ref.type, binary_ref.parent_directory_ref.path, binary_ref.parent_directory_ref.id, binary_ref.id, parent_ref.type, parent_ref.name, parent_ref.pid, parent_ref.binary_ref.type, parent_ref.binary_ref.name, parent_ref.binary_ref.parent_directory_ref.type, parent_ref.binary_ref.parent_directory_ref.path, parent_ref.binary_ref.parent_directory_ref.id, parent_ref.binary_ref.id, parent_ref.command_line, parent_ref.id, binary_ref.parent_directory_ref.x_root, binary_ref.x_root, creator_user_ref.type, creator_user_ref.user_id, creator_user_ref.account_login, creator_user_ref.id, creator_user_ref.x_root]</td>
#     </tr>
#     <tr>
#       <td>Customized Attributes</td>
#       <td>x_contained_by_ref, x_root</td>
#     </tr>
#     <tr>
#       <td>Birth Command</td>
#       <td>get</td>
#     </tr>
#     <tr>
#       <td>Associated Datasource</td>
#       <td>file:///tmp/lab101.json</td>
#     </tr>
#     <tr>
#       <td>Dependent Variables</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>directory*</th>
#       <th>file*</th>
#       <th>ipv4-addr*</th>
#       <th>ipv6-addr*</th>
#       <th>mac-addr*</th>
#       <th>process*</th>
#       <th>user-account*</th>
#       <th>x-ecs-process*</th>
#       <th>x-ecs-user*</th>
#       <th>x-oca-asset*</th>
#       <th>x-oca-event*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>scheduler</td>
#       <td>process</td>
#       <td>1</td>
#       <td>18</td>
#       <td>36</td>
#       <td>36</td>
#       <td>36</td>
#       <td>18</td>
#       <td>18</td>
#       <td>35</td>
#       <td>18</td>
#       <td>18</td>
#       <td>18</td>
#       <td>18</td>
#       <td>18</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# ### 2. How to display entities with complete information in a variable?
#
# Just do `DISP varx` to display all entities with all attributes in variable `varx`:

# %%
DISP scheduler
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>type</th>
#       <th>name</th>
#       <th>pid</th>
#       <th>binary_ref.type</th>
#       <th>binary_ref.name</th>
#       <th>binary_ref.parent_directory_ref.type</th>
#       <th>binary_ref.parent_directory_ref.path</th>
#       <th>binary_ref.parent_directory_ref.id</th>
#       <th>binary_ref.id</th>
#       <th>command_line</th>
#       <th>id</th>
#       <th>x_contained_by_ref</th>
#       <th>first_observed</th>
#       <th>last_observed</th>
#       <th>number_observed</th>
#       <th>parent_ref.type</th>
#       <th>parent_ref.name</th>
#       <th>parent_ref.pid</th>
#       <th>parent_ref.binary_ref.type</th>
#       <th>parent_ref.binary_ref.name</th>
#       <th>parent_ref.binary_ref.parent_directory_ref.type</th>
#       <th>parent_ref.binary_ref.parent_directory_ref.path</th>
#       <th>parent_ref.binary_ref.parent_directory_ref.id</th>
#       <th>parent_ref.binary_ref.id</th>
#       <th>parent_ref.command_line</th>
#       <th>parent_ref.id</th>
#       <th>binary_ref.parent_directory_ref.x_root</th>
#       <th>binary_ref.x_root</th>
#       <th>creator_user_ref.type</th>
#       <th>creator_user_ref.user_id</th>
#       <th>creator_user_ref.account_login</th>
#       <th>creator_user_ref.id</th>
#       <th>creator_user_ref.x_root</th>
#       <th>x_root</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--09186a66-fff6-4905-becd-dd6c939807e0_5</td>
#       <td>file--09186a66-fff6-4905-becd-dd6c939807e0_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--09186a66-fff6-4905-becd-dd6c939807e0_1</td>
#       <td>observed-data--09186a66-fff6-4905-becd-dd6c939807e0</td>
#       <td>2021-04-03T01:45:47.236Z</td>
#       <td>2021-04-03T01:45:47.236Z</td>
#       <td>2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--10a28273-ed70-4e7c-9535-cbcf22b8e7f1_5</td>
#       <td>file--10a28273-ed70-4e7c-9535-cbcf22b8e7f1_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--10a28273-ed70-4e7c-9535-cbcf22b8e7f1_1</td>
#       <td>observed-data--10a28273-ed70-4e7c-9535-cbcf22b8e7f1</td>
#       <td>2021-04-03T01:45:47.895Z</td>
#       <td>2021-04-03T01:45:47.895Z</td>
#       <td>2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--1e1f4e71-093f-4473-88b6-7c09bbd430d4_5</td>
#       <td>file--1e1f4e71-093f-4473-88b6-7c09bbd430d4_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--1e1f4e71-093f-4473-88b6-7c09bbd430d4_1</td>
#       <td>observed-data--1e1f4e71-093f-4473-88b6-7c09bbd430d4</td>
#       <td>2021-04-03T00:23:41.315Z</td>
#       <td>2021-04-03T00:23:41.315Z</td>
#       <td>2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--1ed32af-5475-4446-a3ee-c5fbdfc9e916_5</td>
#       <td>file--1ed32af-5475-4446-a3ee-c5fbdfc9e916_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--1ed32af-5475-4446-a3ee-c5fbdfc9e916_1</td>
#       <td>observed-data--e1ed32af-5475-4446-a3ee-c5fbdfc9e916</td>
#       <td>2021-04-03T01:55:49.589Z</td>
#       <td>2021-04-03T01:55:49.589Z</td>
#       <td>2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--1ffcc0c9-cfc8-4f42-8c45-7b26f25d9cb8_5</td>
#       <td>file--1ffcc0c9-cfc8-4f42-8c45-7b26f25d9cb8_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--1ffcc0c9-cfc8-4f42-8c45-7b26f25d9cb8_1</td>
#       <td>observed-data--1ffcc0c9-cfc8-4f42-8c45-7b26f25d9cb8</td>
#       <td>2021-04-03T01:45:48.790Z</td>
#       <td>2021-04-03T01:45:48.790Z</td>
#       <td>2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--3727dc86-2071-484a-8b33-ed69ac49774d_5</td>
#       <td>file--3727dc86-2071-484a-8b33-ed69ac49774d_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--3727dc86-2071-484a-8b33-ed69ac49774d_1</td>
#       <td>observed-data--3727dc86-2071-484a-8b33-ed69ac49774d</td>
#       <td>2021-04-03T00:04:00.477Z</td>
#       <td>2021-04-03T00:04:00.477Z</td>
#       <td>2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>process</td>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>file</td>
#       <td>svchost.exe</td>
#       <td>directory</td>
#       <td>C:\Windows\System32</td>
#       <td>directory--398d5a8-29f6-4b74-8489-e54a1c2bf088_5</td>
#       <td>file--398d5a8-29f6-4b74-8489-e54a1c2bf088_4</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#       <td>process--398d5a8-29f6-4b74-8489-e54a1c2bf088_1</td>
#       <td>observed-data--a398d5a8-29f6-4b74-8489-e54a1c2bf088</td>
#       <td>2021-04-03T00:25:42.555Z</td>
#       <td>2021-04-03T00:25:42.555Z</td>
#       <td>2</td>
#       <td>None</td>

# %% [markdown]
# ### 3. How to display select attributes of entities in a variable?
#
# You may find the table above actually displays the same entity (process) multiple times, because the entity is referred in different [records/logs](https://kestrel.readthedocs.io/en/latest/language.html#record), each of which gives different attributes of the entity.
#
# You may not need to know the `id` attribute of the entity, which is a Kestrel internal data structure when caching the entitiy. To select attibutes to display, and to automatically deduplicate entities which share the same attributes, you can use the `ATTR` clause of [DISP](https://kestrel.readthedocs.io/en/latest/language.html#disp):

# %%
DISP scheduler ATTR name, pid, command_line
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>pid</th>
#       <th>command_line</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>svchost.exe</td>
#       <td>2224</td>
#       <td>C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. What are the common attributes for a type of entitiy?
#
# You can find the attributes of a type of entitiy in [STIX SCO docs](https://docs.oasis-open.org/cti/stix/v2.1/csprd01/stix-v2.1-csprd01.html#_Toc16070680).
#
# A quickly way is to use `INFO` and get familar with the common attributes:
# - `process`: `name`, `pid`, `command_line`
# - `file`: `name`, `parent_directory_ref.path`
# - `ipv4-addr`: `value`
# - `user-account`: `user_id`
# - `windows-registry-key`: `key`, `values`
# - `network-traffic`: `src_ref.value`, `src_port`, `dst_ref.value`, `dst_port`

# %% [markdown]
# ### 5. Exercise: get and disp remote IPs from the monitored host
#
# The monitored host has local IP `10.171.5.141`.
# 1. Get all `network-traffic` on the day `2021-04-03` from the host (data source: `file:///tmp/lab101.json`).
# 2. Display all remote/destination IPs of the `network-traffic` entities.
#
# Tip: press `TAB` to auto-complete a variable name if the variable has been created in the hunt.

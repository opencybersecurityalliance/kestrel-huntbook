# %% [markdown]
# # Windows Scheduled Tasks Hunt
#
# This huntbook is created with the Kestrel hunting blog: [Building a Huntbook to Discover Persistent Threats from Scheduled Windows Tasks](https://opencybersecurityalliance.org/posts/kestrel-2021-07-26/)

# %% [markdown]
# ### 0. Overview
#
# In Windows 10, scheduled tasks are managed by `svchost.exe`. In this cyber hunting practice, we will start from all scheduled tasks/services to hunt for persistent threats, which uses Windows schedule tasks to start during booting. We will rule out cyber risks of the monitored host.
#
# The purpose of this hunt book is to give an example of STIX pattern matching and hunting from schedule tasks.
#
# The data source of this hunt is a Windows machine with sysmon monitor running. The live trace is streamed to elasticsearch via logstash. And we install Kestrel (`kestrel-lang` and `kestrel-jupyter`) with STIX-Shifter elastic_ecs module (`stix-shifter-modules-elastic_ecs`) to connect to the real-time data source. More information on setting up the entire hunting stack can be found in our [blog](https://opencybersecurityalliance.org/posts/kestrel-2021-07-26/).

# %% [markdown]
# ### 1. Listing All Schedule Tasks On The Monitored Machine
#
# The monitored machine is running Windows 10, and scheduled tasks are run via `svchost.exe` with arguments `-k netsvcs -p -s Schedule`. We can start with a STIX pattern to match all processes with this command line. We randomly select a day to check.

# %%
#### THIS CELL IS FOR ERROR DEMONSTRATION PURPOSE, DELETE THIS CELL WHEN YOU REUSE THE HUNT ####

# create Kestrel variable scheduler with the list of scheduler processes
scheduler = GET process FROM stixshifter://host101
            WHERE [process:command_line = 'C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule']
            START t'2021-04-03T00:00:00Z' STOP t'2021-04-04T00:00:00Z'
# Out:
# [ERROR] DataSourceError: data source internal error: STIX-shifter translation failed. please test data source manually.

# %% [markdown]
# Unfortunately, current version (v3.4.7) of STIX Elastic ECS connector does not support matching process with their `command_line`. Let's fall back to a basic process attribute to get rough data from the data source. After `GET`, Kestrel will cache the retrieved data locally, and we can run more STIX patterns not limited by the incomplete STIX-Shifter implementation.

# %%
# first GET going through STIX shifter
svchost = GET process FROM stixshifter://host101
          WHERE [process:name = 'svchost.exe']
          START t'2021-04-03T00:00:00Z' STOP t'2021-04-04T00:00:00Z'
     
# second GET running locally against the returned/cached data from the first command
# no need to specify time range for GET from a Kestrel variable, check document of GET for more info
# https://kestrel.readthedocs.io/en/latest/language.html#get
scheduler = GET process
            FROM svchost
            WHERE [process:command_line = 'C:\Windows\system32\svchost.exe -k netsvcs -p -s Schedule']
# Out:
# <div><h4>Block Executed in 1 minutes, 14 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>process*</th>
#       <th>file*</th>
#       <th>directory*</th>
#       <th>ipv4-addr*</th>
#       <th>ipv6-addr*</th>
#       <th>mac-addr*</th>
#       <th>user-account*</th>
#       <th>network-traffic*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>svchost</td>
#       <td>process</td>
#       <td>183</td>
#       <td>13579</td>
#       <td>15885</td>
#       <td>16068</td>
#       <td>16066</td>
#       <td>45124</td>
#       <td>24994</td>
#       <td>14762</td>
#       <td>14276</td>
#       <td>12925</td>
#     </tr>
#     <tr>
#       <td>scheduler</td>
#       <td>process</td>
#       <td>2</td>
#       <td>258</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# Great! There are 183 `svchost.exe` on the monitored machine on April 3rd, 2021. And two of them are task scheduler processes.
#
# ### 2. Finding Scheduled Tasks
#
# The `svchost.exe -s Schedule` are system process to start scheduled tasks. It is easy to guess that concrete scheduled tasks are child processes of the two `svchost.exe` processes. Let's get them.

# %%
tasks = FIND process CREATED BY scheduler

DISP tasks ATTR name, command_line
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>command_line</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AppHostRegistrationVerifier.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>AppHostRegistrationVerifier.exe</td>
#       <td>C:\Windows\system32\AppHostRegistrationVerifier.exe</td>
#     </tr>
#     <tr>
#       <td>BackgroundDownload.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>BackgroundDownload.exe</td>
#       <td>"C:\Program Files (x86)\Microsoft Visual Studio\Installer\resources\app\ServiceHub\Services\Microsoft.VisualStudio.Setup.Service\BackgroundDownload.exe"</td>
#     </tr>
#     <tr>
#       <td>CompatTelRunner.exe</td>
#       <td>C:\Windows\system32\compattelrunner.exe</td>
#     </tr>
#     <tr>
#       <td>CompatTelRunner.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>CompatTelRunner.exe</td>
#       <td>C:\Windows\system32\compattelrunner.exe -maintenance</td>
#     </tr>
#     <tr>
#       <td>DeviceCensus.exe</td>
#       <td>C:\Windows\system32\devicecensus.exe</td>
#     </tr>
#     <tr>
#       <td>DeviceCensus.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>DiskSnapshot.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>DiskSnapshot.exe</td>
#       <td>C:\Windows\system32\disksnapshot.exe -z</td>
#     </tr>
#     <tr>
#       <td>MpCmdRun.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>MpCmdRun.exe</td>
#       <td>"C:\ProgramData\Microsoft\Windows Defender\Platform\4.18.2102.4-0\MpCmdRun.exe" -IdleTask -TaskName WdCacheMaintenance</td>
#     </tr>
#     <tr>
#       <td>MpCmdRun.exe</td>
#       <td>"C:\ProgramData\Microsoft\Windows Defender\Platform\4.18.2102.4-0\MpCmdRun.exe" -IdleTask -TaskName WdCleanup</td>
#     </tr>
#     <tr>
#       <td>MpCmdRun.exe</td>
#       <td>"C:\ProgramData\Microsoft\Windows Defender\Platform\4.18.2102.4-0\MpCmdRun.exe" -IdleTask -TaskName WdVerification</td>
#     </tr>
#     <tr>
#       <td>MpCmdRun.exe</td>
#       <td>"C:\ProgramData\Microsoft\Windows Defender\Platform\4.18.2102.4-0\MpCmdRun.exe" Scan -ScheduleJob -ScanTrigger 55 -IdleScheduledJob</td>
#     </tr>
#     <tr>
#       <td>MusNotification.exe</td>
#       <td>C:\Windows\system32\MusNotification.exe</td>
#     </tr>
#     <tr>
#       <td>MusNotification.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>MusNotification.exe</td>
#       <td>C:\Windows\system32\MusNotification.exe LogonUpdateResults</td>
#     </tr>
#     <tr>
#       <td>MusNotification.exe</td>
#       <td>C:\Windows\system32\MusNotification.exe EngagedRebootReminder</td>
#     </tr>
#     <tr>
#       <td>RemoteFXvGPUDisablement.exe</td>
#       <td>C:\Windows\System32\RemoteFXvGPUDisablement.exe Disable</td>
#     </tr>
#     <tr>
#       <td>RemoteFXvGPUDisablement.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>ServerManagerLauncher.exe</td>
#       <td>C:\Windows\system32\ServerManagerLauncher.exe</td>
#     </tr>
#     <tr>
#       <td>ServerManagerLauncher.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>SpeechModelDownload.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>SpeechModelDownload.exe</td>
#       <td>C:\Windows\system32\speech_onecore\common\SpeechModelDownload.exe</td>
#     </tr>
#     <tr>
#       <td>UsoClient.exe</td>
#       <td>C:\Windows\system32\usoclient.exe StartScan</td>
#     </tr>
#     <tr>
#       <td>UsoClient.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>UsoClient.exe</td>
#       <td>C:\Windows\system32\usoclient.exe StartInstall</td>
#     </tr>
#     <tr>
#       <td>amcet.exe</td>
#       <td>c:\programdata\ibm\rii\amcet.exe --logPath C:\ProgramData\IBM\RII\amcet.log</td>
#     </tr>
#     <tr>
#       <td>amcet.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>cleanmgr.exe</td>
#       <td>C:\Windows\system32\cleanmgr.exe /autoclean /d C:</td>
#     </tr>
#     <tr>
#       <td>cleanmgr.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>cmd.exe</td>
#       <td>C:\Windows\system32\cmd.exe /d /c C:\Windows\system32\silcollector.cmd configure</td>
#     </tr>
#     <tr>
#       <td>cmd.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>cmd.exe</td>
#       <td>C:\Windows\SYSTEM32\cmd.exe /c "\\ad.res.ibm.com\sysvol\ad.res.ibm.com\Policies\{6472EF52-C26C-4688-BB66-5DBF9AFFE7D5}\Machine\Scripts\windows.cmd"</td>
#     </tr>
#     <tr>
#       <td>cscript.exe</td>
#       <td>C:\Windows\System32\cscript.exe \\ad.res.ibm.com\sysvol\ad.res.ibm.com\Policies\{F8923319-DFDB-4049-84AC-DB128B775115}\Machine\Scripts\WinUpdates-SPR.vbs</td>
#     </tr>
#     <tr>
#       <td>cscript.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>cscript.exe</td>
#       <td>C:\Windows\System32\cscript.exe \\ad.res.ibm.com\SysVol\ad.res.ibm.com\Policies\{27731C39-DF9A-4907-803A-4FD3CCB360AD}\Machine\Scripts\inventory.vbs</td>
#     </tr>
#     <tr>
#       <td>cscript.exe</td>
#       <td>C:\Windows\System32\cscript.exe \\ad.res.ibm.com\SysVol\ad.res.ibm.com\Policies\{27731C39-DF9A-4907-803A-4FD3CCB360AD}\Machine\Scripts\inventory_v2.vbs</td>
#     </tr>
#     <tr>
#       <td>default-browser-agent.exe</td>
#       <td>"C:\Program Files\Mozilla Firefox\default-browser-agent.exe" do-task "308046B0AF4A39CB"</td>
#     </tr>
#     <tr>
#       <td>default-browser-agent.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>dsregcmd.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>dsregcmd.exe</td>
#       <td>C:\Windows\System32\dsregcmd.exe $(Arg0) $(Arg1) $(Arg2)</td>
#     </tr>
#     <tr>
#       <td>dstokenclean.exe</td>
#       <td>C:\Windows\system32\dstokenclean.exe</td>
#     </tr>
#     <tr>
#       <td>dstokenclean.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>dxgiadaptercache.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>dxgiadaptercache.exe</td>
#       <td>C:\Windows\system32\dxgiadaptercache.exe</td>
#     </tr>
#     <tr>
#       <td>lpremove.exe</td>
#       <td>C:\Windows\system32\lpremove.exe</td>
#     </tr>
#     <tr>
#       <td>lpremove.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>motd.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>motd.exe</td>
#       <td>\\ad.res.ibm.com\sysvol\ad.res.ibm.com\Policies\{C826ADF6-6390-4C28-9AE0-7F4D7D7C0756}\Machine\Scripts\motd.exe</td>
#     </tr>
#     <tr>
#       <td>reg.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>reg.exe</td>
#       <td>c:\windows\system32\reg.exe add HKEY_LOCAL_MACHINE\SOFTWARE\IBM\HRL  /v WSUSAlert /t reg_dword /d 0 /f</td>
#     </tr>
#     <tr>
#       <td>rundll32.exe</td>
#       <td>C:\Windows\system32\rundll32.exe /d acproxy.dll,PerformAutochkOperations</td>
#     </tr>
#     <tr>
#       <td>rundll32.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>sc.exe</td>
#       <td>C:\Windows\system32\sc.exe start wuauserv</td>
#     </tr>
#     <tr>
#       <td>sc.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>sc.exe</td>
#       <td>C:\Windows\system32\sc.exe start w32time task_started</td>
#     </tr>
#     <tr>
#       <td>schtasks.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>schtasks.exe</td>
#       <td>C:\Windows\System32\schtasks.exe /CHANGE /TN AD-RES\RII-Set_User_Last_Logon /ru users</td>
#     </tr>
#     <tr>
#       <td>setdata.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>setdata.exe</td>
#       <td>\\ad.res.ibm.com\SysVol\ad.res.ibm.com\Policies\{D099D411-A214-490A-9AD3-7F38306BB4FA}\Machine\Scripts\setdata.exe</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe SYSTEM</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe KEYROAMING</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe Install $(Arg0)</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe ExploitGuardPolicy</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe {222A245B-E637-4AE9-A93F-A59CA119A75E}</td>
#     </tr>
#     <tr>
#       <td>taskhostw.exe</td>
#       <td>taskhostw.exe /Runt

# %% [markdown]
# ### 3. Drilling Down on a Scheduled Task
#
# While most process names are common, an uncommon one is `amcet.exe`. Neither Google or VirusTotal has information about this proprietary process. From its command line, we can guess this is a legitimate process owned by IBM. Let's pull out its details to check.

# %%
# get only the amcet processes from all scheduled tasks
amcet = GET process FROM tasks WHERE [process:name = 'amcet.exe']
# Out:
# <div><h4>Block Executed in 1 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>process*</th>
#       <th>file*</th>
#       <th>directory*</th>
#       <th>ipv4-addr*</th>
#       <th>ipv6-addr*</th>
#       <th>mac-addr*</th>
#       <th>user-account*</th>
#       <th>network-traffic*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>amcet</td>
#       <td>process</td>
#       <td>24</td>
#       <td>165</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# The execution summary does not show any related records cached since they are already retrieved in the last hunt step when generating variable `tasks`. We can brute force check whether there are child processes and network activities of the processes in `amcet`.

# %%
# find and display their child processes
amcet_child = FIND process CREATED BY amcet
DISP amcet_child ATTR name, command_line

# find and display their network traffic
nt = FIND network-traffic CREATED BY amcet
DISP nt ATTR dst_ref.value, dst_port
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>command_line</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>conhost.exe</td>
#       <td>\??\C:\Windows\system32\conhost.exe 0xffffffff -ForceV1</td>
#     </tr>
#     <tr>
#       <td>conhost.exe</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>powershell.exe</td>
#       <td>powershell.exe -NoExit -Command -</td>
#     </tr>
#     <tr>
#       <td>powershell.exe</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dst_ref.value</th>
#       <th>dst_port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>9.148.5.93</td>
#       <td>443</td>
#     </tr>
#   </tbody>
# </table>
# <div><h4>Block Executed in 5 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>process*</th>
#       <th>file*</th>
#       <th>directory*</th>
#       <th>ipv4-addr*</th>
#       <th>ipv6-addr*</th>
#       <th>mac-addr*</th>
#       <th>user-account*</th>
#       <th>network-traffic*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>amcet_child</td>
#       <td>process</td>
#       <td>45</td>
#       <td>321</td>
#       <td>2443</td>
#       <td>2488</td>
#       <td>2474</td>
#       <td>4104</td>
#       <td>1695</td>
#       <td>1689</td>
#       <td>1156</td>
#       <td>366</td>
#     </tr>
#     <tr>
#       <td>nt</td>
#       <td>network-traffic</td>
#       <td>23</td>
#       <td>23</td>
#       <td>1673</td>
#       <td>1673</td>
#       <td>1660</td>
#       <td>2386</td>
#       <td>1096</td>
#       <td>1094</td>
#       <td>671</td>
#       <td>77</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# The only IP that is accessed by `amcet` is an IBM internal IP, which looks safe. But there is still a chance that the IP is infected and the threat goes from it to the monitored Windows machine. The two child processes of `amcet` are powerful system management processes, and `conhost` with arguments `0xffffffff -ForceV1` can access kernel space and is used in many attacks. Let's further check whether there is any process spawned from the two.

# %%
# find child processes of amcet_child
amcet_cc = FIND process CREATED BY amcet_child
DISP amcet_cc ATTR name, command_line

# find files read/written/executed by amcet_child
# Kestrel v1.0.8 only resolves the generic relation LINKED into STIX 2.0 references,
# which is limited to execution relation between processes and executables
amcet_f = FIND file LINKED amcet_child
DISP amcet_f ATTR name, parent_directory_ref.path
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>parent_directory_ref.path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>conhost.exe</td>
#       <td>C:\Windows\System32</td>
#     </tr>
#     <tr>
#       <td>powershell.exe</td>
#       <td>C:\Windows\System32\WindowsPowerShell\v1.0</td>
#     </tr>
#   </tbody>
# </table>
# <div><h4>Block Executed in 7 seconds</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>VARIABLE</th>
#       <th>TYPE</th>
#       <th>#(ENTITIES)</th>
#       <th>#(RECORDS)</th>
#       <th>process*</th>
#       <th>file*</th>
#       <th>directory*</th>
#       <th>ipv4-addr*</th>
#       <th>ipv6-addr*</th>
#       <th>mac-addr*</th>
#       <th>user-account*</th>
#       <th>network-traffic*</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>amcet_cc</td>
#       <td>process</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>amcet_f</td>
#       <td>file</td>
#       <td>2</td>
#       <td>1563</td>
#       <td>4253</td>
#       <td>4251</td>
#       <td>4239</td>
#       <td>6982</td>
#       <td>2927</td>
#       <td>2921</td>
#       <td>1896</td>
#       <td>573</td>
#     </tr>
#   </tbody>
# </table><p>*Number of related records cached.</p></div>

# %% [markdown]
# Fortunately, there is no spawned processes. And the only files associated with `amcet_child` are the executables of the processes.
#
# We can further check other scheduled tasks such as `wscript.exe` and `setdata.exe`. We can also construct common STIX patterns for situations other than matching scheduled tasks. The STIX patterns can be reused in different hunts, as well as the part/overall of this huntflow.
